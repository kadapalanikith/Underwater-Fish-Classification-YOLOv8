# %%
# !pip install ultralytics kaggle
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 50.7 MB/s eta 0:00:00
# ...

# %%
# %%writefile kaggle.json
# {
#   "username": "kadapalanikith",
#   "key": "KGAT_c6a6115d92b5c7a4549858d9b9b35327"
# }
# Out:
# Writing kaggle.json

# %%
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets list
# Out:
# ref                                                                 title                                                     size  lastUpdated                 downloadCount  voteCount  usabilityRating
# ------------------------------------------------------------------  --------------------------------------------------  ----------  --------------------------  -------------  ---------  ---------------
# saidaminsaidaxmadov/chocolate-sales                                 Chocolate Sales                                         468320  2026-01-04 14:23:35.490000          11417        189  1.0
# ibrahimshahrukh/global-price-of-healthy-diet-dataset                Cost of Healthy Diet by Country (2017-2024)              14103  2026-01-31 02:52:05.010000            485         29  1.0
# rockyt07/social-media-user-analysis                                 Social Media User Analysis                           247842357  2026-01-14 02:28:41.970000           6928        143  1.0
# ...

# %%
# !kaggle datasets download -d zehraatlgan/fish-detection
# !unzip fish-detection.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: train/labels/Zebrafish-Not-Green-219-_png_jpg.rf.716f6ad63ab7e3041ad70a2d22d64e17.txt
#   inflating: train/labels/Zebrafish-Not-Green-219-_png_jpg.rf.96085f9ee2b5d019d20464cab5772857.txt
#   inflating: train/labels/Zebrafish-Not-Green-219-_png_jpg.rf.eb3e1cf1e028ce885a2f464a01c8ed9a.txt
#   inflating: train/labels/Zebrafish-Not-Green-219-_png_jpg.rf.fc2c51426b56c5a8103e59e108a45e29.txt
#   inflating: train/labels/Zebrafish-Not-Green-220-_png_jpg.rf.08e859167b4895369fd57a1af8978fca.txt
#   inflating: train/labels/Zebrafish-Not-Green-220-_png_jpg.rf.251d6aadd72d3929a0e27be9abe6d726.txt
#   inflating: train/labels/Zebrafish-Not-Green-220-_png_jpg.rf.8c0f0282aa47c0c79f73f90a2e1a638c.txt
#   inflating: train/labels/Zebrafish-Not-Green-220-_png_jpg.rf.c572c6e44e877f20a2ded4c5c70d6041.txt
#   inflating: train/labels/Zebrafish-Not-Green-221-_png_jpg.rf.9f0bb8002fa4f7da29ece35bccd8b1db.txt
# ...

# %%
# !ls
# Out:
# data.yaml	    README.dataset.txt	 sample_data  train
# fish-detection.zip  README.roboflow.txt  test	      valid

# %%
# %%writefile data.yaml
# train: train/images
# val: valid/images
# test: test/images
#
# nc: 13
# names:
#   - AngelFish
#   - BlueTang
#   - ButterflyFish
#   - ClownFish
#   - GoldFish
#   - Gourami
#   - MorishIdol
#   - PlatyFish
#   - RibbonedSweetlips
#   - ThreeStripedDamselfish
#   - YellowCichlid
#   - YellowTang
#   - ZebraFish
# Out:
# Overwriting data.yaml

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="data.yaml",   # the multi-class yaml
    epochs=10,
    imgsz=640
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.9 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from google.colab import files
files.download("runs/detect/train/weights/best.pt")
